# %% [markdown]
# <a href="https://colab.research.google.com/github/remizah/Luminar_projects/blob/main/Luminar_SLR_salary.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
df=pd.read_csv('/content/drive/MyDrive/Datasets/Salary_Data.csv')
df
# Out:
#     YearsExperience    Salary
# 0               1.1   39343.0
# 1               1.3   46205.0
# 2               1.5   37731.0
# 3               2.0   43525.0
# 4               2.2   39891.0
# 5               2.9   56642.0
# 6               3.0   60150.0
# 7               3.2   54445.0
# 8               3.2   64445.0
# 9               3.7   57189.0
# 10              3.9   63218.0
# 11              4.0   55794.0
# 12              4.0   56957.0
# 13              4.1   57081.0
# 14              4.5   61111.0
# 15              4.9   67938.0
# 16              5.1   66029.0
# 17              5.3   83088.0
# 18              5.9   81363.0
# 19              6.0   93940.0
# 20              6.8   91738.0
# 21              7.1   98273.0
# 22              7.9  101302.0
# 23              8.2  113812.0
# 24              8.7  109431.0
# 25              9.0  105582.0
# 26              9.5  116969.0
# 27              9.6  112635.0
# 28             10.3  122391.0
# 29             10.5  121872.0

# %%
X=df.iloc[:,0:1]
X
# Out:
#     YearsExperience
# 0               1.1
# 1               1.3
# 2               1.5
# 3               2.0
# 4               2.2
# 5               2.9
# 6               3.0
# 7               3.2
# 8               3.2
# 9               3.7
# 10              3.9
# 11              4.0
# 12              4.0
# 13              4.1
# 14              4.5
# 15              4.9
# 16              5.1
# 17              5.3
# 18              5.9
# 19              6.0
# 20              6.8
# 21              7.1
# 22              7.9
# 23              8.2
# 24              8.7
# 25              9.0
# 26              9.5
# 27              9.6
# 28             10.3
# 29             10.5

# %%
y=df.iloc[:,-1]
y
# Out:
# 0      39343.0
# 1      46205.0
# 2      37731.0
# 3      43525.0
# 4      39891.0
# 5      56642.0
# 6      60150.0
# 7      54445.0
# 8      64445.0
# 9      57189.0
# 10     63218.0
# 11     55794.0
# 12     56957.0
# 13     57081.0
# 14     61111.0
# 15     67938.0
# 16     66029.0
# 17     83088.0
# 18     81363.0
# 19     93940.0
# 20     91738.0
# 21     98273.0
# 22    101302.0
# 23    113812.0
# 24    109431.0
# 25    105582.0
# 26    116969.0
# 27    112635.0
# 28    122391.0
# 29    121872.0
# Name: Salary, dtype: float64

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.3,random_state=1)

# %%
from sklearn.linear_model import LinearRegression
lr=LinearRegression()
lr.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
X_test
# Out:
#     YearsExperience
# 17              5.3
# 21              7.1
# 10              3.9
# 19              6.0
# 14              4.5
# 20              6.8
# 26              9.5
# 3               2.0
# 24              8.7

# %%
y_pred=lr.predict(X_test)
y_pred
# Out:
# array([ 74821.41578619,  91385.43626305,  61938.28874864,  81262.97930497,
#         67459.62890759,  88624.76618357, 113470.79689886,  44454.04491195,
#        106109.01002026])

# %%
y_test.values
# Out:
# array([ 83088.,  98273.,  63218.,  93940.,  61111.,  91738., 116969.,
#         43525., 109431.])

# %%
result=pd.DataFrame({'Actual':y_test,'Predicted':y_pred})
result
# Out:
#       Actual      Predicted
# 17   83088.0   74821.415786
# 21   98273.0   91385.436263
# 10   63218.0   61938.288749
# 19   93940.0   81262.979305
# 14   61111.0   67459.628908
# 20   91738.0   88624.766184
# 26  116969.0  113470.796899
# 3    43525.0   44454.044912
# 24  109431.0  106109.010020

# %%
import matplotlib.pyplot as plt
plt.xlabel("Years of experience")
plt.ylabel("Salary")
plt.title("EXPERIENCE vs SALARY")
plt.scatter(X_train,y_train)
plt.scatter(X_test,y_pred)
plt.plot(X_test,y_pred,color='red')
plt.show()

# %%
plt.xlabel("Years of experience")
plt.ylabel("Salary")
plt.title("Salary vs Experience")
plt.scatter(X_test,y_test)
plt.scatter(X_test,y_pred,color='red')
plt.show()

# %%
print("slope",lr.coef_)
print("Y intercept:",lr.intercept_)
# Out:
# slope [9202.23359825]
# Y intercept: 26049.577715443353

# %%
9202.23359825*7.1+26049.577715443353
# Out:
# 91385.43626301835

# %%
from sklearn.metrics import r2_score
print("r2_score:",r2_score(y_test,y_pred))
# Out:
# r2_score: 0.9248580247217075

# %%
from sklearn.metrics import mean_absolute_error,mean_squared_error
import numpy as np
print("MAE:",mean_absolute_error(y_test,y_pred))
print("MSE:",mean_squared_error(y_test,y_pred))
print("RMSE:",np.sqrt(mean_squared_error(y_test,y_pred)))
# Out:
# MAE: 5146.886734888234
# MSE: 39139215.99958858
# RMSE: 6256.134269625979
