# %% [markdown]
# <a href="https://colab.research.google.com/github/remizah/Luminar_projects/blob/main/Luminar_traindata_MLR.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
df=pd.read_csv('/content/drive/MyDrive/Datasets/train-data.csv')
df
# Out:
#       Unnamed: 0                              Name    Location  Year  \
# 0              0            Maruti Wagon R LXI CNG      Mumbai  2010
# 1              1  Hyundai Creta 1.6 CRDi SX Option        Pune  2015
# 2              2                      Honda Jazz V     Chennai  2011
# 3              3                 Maruti Ertiga VDI     Chennai  2012
# 4              4   Audi A4 New 2.0 TDI Multitronic  Coimbatore  2013
# ...          ...                               ...         ...   ...
# 6014        6014                  Maruti Swift VDI       Delhi  2014
# 6015        6015          Hyundai Xcent 1.1 CRDi S      Jaipur  2015
# 6016        6016             Mahindra Xylo D4 BSIV      Jaipur  2012
# 6017        6017                Maruti Wagon R VXI     Kolkata  2013
# 6018        6018             Chevrolet Beat Diesel   Hyderabad  2011
#
#       Kilometers_Driven Fuel_Type Transmission Owner_Type     Mileage  \
# ...

# %%
df['Brand'] = df['Name'].apply(lambda x: x.split()[0])
df
# Out:
#       Unnamed: 0                              Name    Location  Year  \
# 0              0            Maruti Wagon R LXI CNG      Mumbai  2010
# 1              1  Hyundai Creta 1.6 CRDi SX Option        Pune  2015
# 2              2                      Honda Jazz V     Chennai  2011
# 3              3                 Maruti Ertiga VDI     Chennai  2012
# 4              4   Audi A4 New 2.0 TDI Multitronic  Coimbatore  2013
# ...          ...                               ...         ...   ...
# 6014        6014                  Maruti Swift VDI       Delhi  2014
# 6015        6015          Hyundai Xcent 1.1 CRDi S      Jaipur  2015
# 6016        6016             Mahindra Xylo D4 BSIV      Jaipur  2012
# 6017        6017                Maruti Wagon R VXI     Kolkata  2013
# 6018        6018             Chevrolet Beat Diesel   Hyderabad  2011
#
#       Kilometers_Driven Fuel_Type Transmission Owner_Type     Mileage  \
# ...

# %%
df.isna().sum()
# Out:
# Unnamed: 0              0
# Name                    0
# Location                0
# Year                    0
# Kilometers_Driven       0
# Fuel_Type               0
# Transmission            0
# Owner_Type              0
# Mileage                 2
# Engine                 36
# Power                  36
# Seats                  42
# New_Price            5195
# Price                   0
# Brand                   0
# dtype: int64

# %%
df.drop(['Unnamed: 0', 'Name', 'New_Price'],axis=1, inplace=True)
df
# Out:
#         Location  Year  Kilometers_Driven Fuel_Type Transmission Owner_Type  \
# 0         Mumbai  2010              72000       CNG       Manual      First
# 1           Pune  2015              41000    Diesel       Manual      First
# 2        Chennai  2011              46000    Petrol       Manual      First
# 3        Chennai  2012              87000    Diesel       Manual      First
# 4     Coimbatore  2013              40670    Diesel    Automatic     Second
# ...          ...   ...                ...       ...          ...        ...
# 6014       Delhi  2014              27365    Diesel       Manual      First
# 6015      Jaipur  2015             100000    Diesel       Manual      First
# 6016      Jaipur  2012              55000    Diesel       Manual     Second
# 6017     Kolkata  2013              46000    Petrol       Manual      First
# 6018   Hyderabad  2011              47000    Diesel       Manual      First
#
# ...

# %%
df.dtypes
# Out:
# Location              object
# Year                   int64
# Kilometers_Driven      int64
# Fuel_Type             object
# Transmission          object
# Owner_Type            object
# Mileage               object
# Engine                object
# Power                 object
# Seats                float64
# Price                float64
# Brand                 object
# dtype: object

# %%
#mode
df['Seats']=df['Seats'].fillna(df['Seats'].mode()[0])

# %%
df.isna().sum()
# Out:
# Location              0
# Year                  0
# Kilometers_Driven     0
# Fuel_Type             0
# Transmission          0
# Owner_Type            0
# Mileage               2
# Engine               36
# Power                36
# Seats                 0
# Price                 0
# Brand                 0
# dtype: int64

# %%
df['Mileage']=df['Mileage'].str.replace('km/kg','')
df['Mileage']=df['Mileage'].str.replace('kmpl','')
df
# Out:
#         Location  Year  Kilometers_Driven Fuel_Type Transmission Owner_Type  \
# 0         Mumbai  2010              72000       CNG       Manual      First
# 1           Pune  2015              41000    Diesel       Manual      First
# 2        Chennai  2011              46000    Petrol       Manual      First
# 3        Chennai  2012              87000    Diesel       Manual      First
# 4     Coimbatore  2013              40670    Diesel    Automatic     Second
# ...          ...   ...                ...       ...          ...        ...
# 6014       Delhi  2014              27365    Diesel       Manual      First
# 6015      Jaipur  2015             100000    Diesel       Manual      First
# 6016      Jaipur  2012              55000    Diesel       Manual     Second
# 6017     Kolkata  2013              46000    Petrol       Manual      First
# 6018   Hyderabad  2011              47000    Diesel       Manual      First
#
# ...

# %%
df['Power']=df['Power'].str.replace('bhp','')
df
# df['Power']=df['Power'].str.replace('null ','0')
# Out:
#         Location  Year  Kilometers_Driven Fuel_Type Transmission Owner_Type  \
# 0         Mumbai  2010              72000       CNG       Manual      First
# 1           Pune  2015              41000    Diesel       Manual      First
# 2        Chennai  2011              46000    Petrol       Manual      First
# 3        Chennai  2012              87000    Diesel       Manual      First
# 4     Coimbatore  2013              40670    Diesel    Automatic     Second
# ...          ...   ...                ...       ...          ...        ...
# 6014       Delhi  2014              27365    Diesel       Manual      First
# 6015      Jaipur  2015             100000    Diesel       Manual      First
# 6016      Jaipur  2012              55000    Diesel       Manual     Second
# 6017     Kolkata  2013              46000    Petrol       Manual      First
# 6018   Hyderabad  2011              47000    Diesel       Manual      First
#
#      Mileage   Engine   Power  Seats  Price      Brand
# ...

# %%
df['Engine']=df['Engine'].str.replace('CC','')
df
# Out:
#         Location  Year  Kilometers_Driven Fuel_Type Transmission Owner_Type  \
# 0         Mumbai  2010              72000       CNG       Manual      First
# 1           Pune  2015              41000    Diesel       Manual      First
# 2        Chennai  2011              46000    Petrol       Manual      First
# 3        Chennai  2012              87000    Diesel       Manual      First
# 4     Coimbatore  2013              40670    Diesel    Automatic     Second
# ...          ...   ...                ...       ...          ...        ...
# 6014       Delhi  2014              27365    Diesel       Manual      First
# 6015      Jaipur  2015             100000    Diesel       Manual      First
# 6016      Jaipur  2012              55000    Diesel       Manual     Second
# 6017     Kolkata  2013              46000    Petrol       Manual      First
# 6018   Hyderabad  2011              47000    Diesel       Manual      First
#
#      Mileage Engine   Power  Seats  Price      Brand
# ...

# %%
df.dtypes
# Out:
# Location              object
# Year                   int64
# Kilometers_Driven      int64
# Fuel_Type             object
# Transmission          object
# Owner_Type            object
# Mileage               object
# Engine                object
# Power                 object
# Seats                float64
# Price                float64
# Brand                 object
# dtype: object

# %%
df['Mileage']=df['Mileage'].astype(float)
df.dtypes
# Out:
# Location              object
# Year                   int64
# Kilometers_Driven      int64
# Fuel_Type             object
# Transmission          object
# Owner_Type            object
# Mileage              float64
# Engine                object
# Power                 object
# Seats                float64
# Price                float64
# Brand                 object
# dtype: object

# %%
df.loc[df['Power']=='null']
# Out:
# Empty DataFrame
# Columns: [Location, Year, Kilometers_Driven, Fuel_Type, Transmission, Owner_Type, Mileage, Engine, Power, Seats, Price, Brand]
# Index: []

# %%
df['Power']=df['Power'].str.replace('null',"0")

# %%
df['Power']=df['Power'].astype(float)

# %%
df.dtypes
# Out:
# Location              object
# Year                   int64
# Kilometers_Driven      int64
# Fuel_Type             object
# Transmission          object
# Owner_Type            object
# Mileage              float64
# Engine                object
# Power                float64
# Seats                float64
# Price                float64
# Brand                 object
# dtype: object

# %%
df['Mileage']=df['Mileage'].fillna(df['Mileage'].mean())
df['Engine']=df['Engine'].fillna(df['Engine'].mode()[0])

# %%
df.isna().sum()
# Out:
# Location              0
# Year                  0
# Kilometers_Driven     0
# Fuel_Type             0
# Transmission          0
# Owner_Type            0
# Mileage               0
# Engine                0
# Power                36
# Seats                 0
# Price                 0
# Brand                 0
# dtype: int64

# %%
import numpy as np
df['Power']=df['Power'].replace(0,np.NaN)

# %%
df.isna().sum()
# Out:
# Location               0
# Year                   0
# Kilometers_Driven      0
# Fuel_Type              0
# Transmission           0
# Owner_Type             0
# Mileage                0
# Engine                 0
# Power                143
# Seats                  0
# Price                  0
# Brand                  0
# dtype: int64

# %%
df.Power
# Out:
# 0        58.16
# 1       126.20
# 2        88.70
# 3        88.76
# 4       140.80
#          ...
# 6014     74.00
# 6015     71.00
# 6016    112.00
# 6017     67.10
# 6018     57.60
# Name: Power, Length: 6019, dtype: float64

# %%
mdn=df['Power'].median()
mdn
# Out:
# 97.7

# %%
df['Power']=df['Power'].fillna(df['Power'].mode()[0])

# %%
df.isna().sum()
# Out:
# Location             0
# Year                 0
# Kilometers_Driven    0
# Fuel_Type            0
# Transmission         0
# Owner_Type           0
# Mileage              0
# Engine               0
# Power                0
# Seats                0
# Price                0
# Brand                0
# dtype: int64

# %%
df.dtypes
# Out:
# Location              object
# Year                   int64
# Kilometers_Driven      int64
# Fuel_Type             object
# Transmission          object
# Owner_Type            object
# Mileage              float64
# Engine                object
# Power                float64
# Seats                float64
# Price                float64
# Brand                 object
# dtype: object

# %%
from sklearn.preprocessing import LabelEncoder
encoder=LabelEncoder()
df['Location']=encoder.fit_transform(df['Location'])
df['Fuel_Type']=encoder.fit_transform(df['Fuel_Type'])
df['Transmission']=encoder.fit_transform(df['Transmission'])
df['Owner_Type']=encoder.fit_transform(df['Owner_Type'])
df['Brand']=encoder.fit_transform(df['Brand'])

# %%
df.dtypes
# Out:
# Location               int64
# Year                   int64
# Kilometers_Driven      int64
# Fuel_Type              int64
# Transmission           int64
# Owner_Type             int64
# Mileage              float64
# Engine                object
# Power                float64
# Seats                float64
# Price                float64
# Brand                  int64
# dtype: object

# %%
df
# Out:
#       Location  Year  Kilometers_Driven  Fuel_Type  Transmission  Owner_Type  \
# 0            9  2010              72000          0             1           0
# 1           10  2015              41000          1             1           0
# 2            2  2011              46000          4             1           0
# 3            2  2012              87000          1             1           0
# 4            3  2013              40670          1             0           2
# ...        ...   ...                ...        ...           ...         ...
# 6014         4  2014              27365          1             1           0
# 6015         6  2015             100000          1             1           0
# 6016         6  2012              55000          1             1           2
# 6017         8  2013              46000          4             1           0
# 6018         5  2011              47000          1             1           0
#
# ...

# %%
X=df.drop(['Price'],axis=1)
X
# Out:
#       Location  Year  Kilometers_Driven  Fuel_Type  Transmission  Owner_Type  \
# 0            9  2010              72000          0             1           0
# 1           10  2015              41000          1             1           0
# 2            2  2011              46000          4             1           0
# 3            2  2012              87000          1             1           0
# 4            3  2013              40670          1             0           2
# ...        ...   ...                ...        ...           ...         ...
# 6014         4  2014              27365          1             1           0
# 6015         6  2015             100000          1             1           0
# 6016         6  2012              55000          1             1           2
# 6017         8  2013              46000          4             1           0
# 6018         5  2011              47000          1             1           0
#
#       Mileage Engine   Power  Seats  Brand
# ...

# %%
y=df.iloc[:,-2]
y
# Out:
# 0        1.75
# 1       12.50
# 2        4.50
# 3        6.00
# 4       17.74
#         ...
# 6014     4.75
# 6015     4.00
# 6016     2.90
# 6017     2.65
# 6018     2.50
# Name: Price, Length: 6019, dtype: float64

# %% [markdown]
# **Using Scaler**

# %%
from sklearn.preprocessing import MinMaxScaler
Scaler=MinMaxScaler()
X=Scaler.fit_transform(X)

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,random_state=18,test_size=0.3)

# %%
from sklearn.linear_model import LinearRegression
mlr=LinearRegression()
mlr.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred=mlr.predict(X_test)

# %%
import numpy as np
from sklearn.metrics import r2_score,mean_absolute_error,mean_squared_error
print('r2 score:',r2_score(y_test,y_pred))
print('MAE:',mean_absolute_error(y_test,y_pred))
print('MSE:',mean_squared_error(y_test,y_pred))
print('RMSE:',np.sqrt(mean_squared_error(y_test,y_pred)))
# Out:
# r2 score: 0.7251592588684272
# MAE: 3.752294014972994
# MSE: 33.79446587775979
# RMSE: 5.81330077303418

# %%
from sklearn.metrics import r2_score
print(r2_score(y_test,y_pred))
# Out:
# 0.7251592588684272

# %% [markdown]
# **Using another Regression Algorithm,**

# %%
from sklearn.neighbors import KNeighborsRegressor
knn=KNeighborsRegressor(n_neighbors=5)
knn.fit(X_train,y_train)
# Out:
# KNeighborsRegressor()

# %%
y_predknn=knn.predict(X_test)
y_predknn
# Out:
# array([30.99 ,  1.77 ,  5.9  , ...,  5.502,  5.08 ,  2.85 ])

# %%
X_test
# Out:
# array([[0.4       , 0.80952381, 0.00566615, ..., 0.2919361 , 0.5       ,
#         0.53333333],
#        [0.        , 0.42857143, 0.01105091, ..., 0.02301255, 0.5       ,
#         0.6       ],
#        [0.9       , 0.76190476, 0.01067628, ..., 0.1058197 , 0.5       ,
#         0.26666667],
#        ...,
#        [0.6       , 0.80952381, 0.00966625, ..., 0.10384176, 0.5       ,
#         0.96666667],
#        [0.        , 0.71428571, 0.01089706, ..., 0.07531381, 0.8       ,
#         0.13333333],
#        [0.5       , 0.57142857, 0.0076662 , ..., 0.08501331, 0.5       ,
#         0.33333333]])

# %%
print(r2_score(y_test,y_predknn))
# Out:
# 0.7809269327585726
